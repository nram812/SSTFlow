# %%
import xarray as xr

# %%
df = xr.open_dataset(r'/esi/project/niwa03712/rampaln/PUBLICATIONS/2026/SSTDownscaling/sst_5km_NOAA_Australia.nc')

# %%
df.analysed_sst.isel(time =9212).plot(cmap ='RdBu_r')
# maybe train from 1996 onwards
